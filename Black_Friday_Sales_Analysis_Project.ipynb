# %% [markdown]
# **Black Friday Sales Analysis Data Analysis**

# %%
import pandas as pd
df=pd.read_csv('BlackFriday.csv')
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69255 entries, 0 to 69254
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     69255 non-null  int64
#  1   Product_ID                  69255 non-null  object
#  2   Gender                      69255 non-null  object
#  3   Age                         69255 non-null  object
#  4   Occupation                  69255 non-null  int64
#  5   City_Category               69255 non-null  object
#  6   Stay_In_Current_City_Years  69255 non-null  object
#  7   Marital_Status              69255 non-null  int64
#  8   Product_Category_1          69255 non-null  int64
#  9   Product_Category_2          47538 non-null  float64
#  10  Product_Category_3          21067 non-null  float64
#  11  Purchase                    69254 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 6.3+ MB

# %%
df
# Out:
#        User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0      1000001  P00069042      F   0-17          10             A
# 1      1000001  P00248942      F   0-17          10             A
# 2      1000001  P00087842      F   0-17          10             A
# 3      1000001  P00085442      F   0-17          10             A
# 4      1000002  P00285442      M    55+          16             C
# ...        ...        ...    ...    ...         ...           ...
# 69250  1004581  P00315842      M  26-35           1             C
# 69251  1004581  P00118742      M  26-35           1             C
# 69252  1004581  P00120342      M  26-35           1             C
# 69253  1004581  P00114442      M  26-35           1             C
# 69254  1004582  P00110842      F  26-35           0             A
#
#       Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                              2               0                   3
# ...

# %%
df.isnull()
# Out:
#        User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0        False       False   False  False       False          False
# 1        False       False   False  False       False          False
# 2        False       False   False  False       False          False
# 3        False       False   False  False       False          False
# 4        False       False   False  False       False          False
# ...        ...         ...     ...    ...         ...            ...
# 69250    False       False   False  False       False          False
# 69251    False       False   False  False       False          False
# 69252    False       False   False  False       False          False
# 69253    False       False   False  False       False          False
# 69254    False       False   False  False       False          False
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                           0
# Product_ID                        0
# Gender                            0
# Age                               0
# Occupation                        0
# City_Category                     0
# Stay_In_Current_City_Years        0
# Marital_Status                    0
# Product_Category_1                0
# Product_Category_2            21717
# Product_Category_3            48188
# Purchase                          1
# dtype: int64

# %%
df.dropna().isna()
# Out:
#        User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 1        False       False   False  False       False          False
# 6        False       False   False  False       False          False
# 13       False       False   False  False       False          False
# 14       False       False   False  False       False          False
# 16       False       False   False  False       False          False
# ...        ...         ...     ...    ...         ...            ...
# 69210    False       False   False  False       False          False
# 69216    False       False   False  False       False          False
# 69217    False       False   False  False       False          False
# 69220    False       False   False  False       False          False
# 69242    False       False   False  False       False          False
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
df.dropna().isnull()
# Out:
#        User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0        False       False   False  False       False          False
# 1        False       False   False  False       False          False
# 2        False       False   False  False       False          False
# 3        False       False   False  False       False          False
# 4        False       False   False  False       False          False
# ...        ...         ...     ...    ...         ...            ...
# 69249    False       False   False  False       False          False
# 69250    False       False   False  False       False          False
# 69251    False       False   False  False       False          False
# 69252    False       False   False  False       False          False
# 69253    False       False   False  False       False          False
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %% [markdown]
# **Black Friday-Analyzing Columns**

# %%
df["User_ID"].nunique()
# Out:
# 5631

# %%
df["User_ID"].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004554, 1004559, 1004564])

# %%
df["Product_ID"].nunique()
# Out:
# 3201

# %%
df["Product_ID"].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00131842',
#        'P00257242', 'P00306542'], dtype=object)

# %%
df["Gender"].nunique()
# Out:
# 2

# %%
df["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df["Age"].nunique()
# Out:
# 7

# %%
df["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df["Marital_Status"].unique()
# Out:
# array([0, 1])

# %%
df["Product_Category_1"].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9])

# %%
df["Purchase"].sum()
# Out:
# 643453586.0

# %%
df["Purchase"].sum()/len(df["Purchase"])
# Out:
# 9291.077698361129

# %%
for column in df.columns:
    print(column, df[column].nunique())
# Out:
# User_ID 5631
# Product_ID 3201
# Gender 2
# Age 7
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 18
# Purchase 12791

# %% [markdown]
# **Black Friday-Analyzing Gender**

# %%
len(df[df["Gender"]=="M"]),len(df[df["Gender"]=="F"])
# Out:
# (52765, 16490)

# %%
import pandas as pd
data=pd.DataFrame({'Ratio':[len(df[df["Gender"]=="M"]),len(df[df["Gender"]=="F"])]},index=["male","female"])
print(data)
# Out:
#         Ratio
# male    52765
# female  16490

# %%
data.plot.pie(y="Ratio",figsize=(4,4),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby("Gender").size()
# Out:
# Gender
# F    16490
# M    52765
# dtype: int64

# %% [markdown]
# ****

# %%
df.groupby("Gender").size().plot(kind="pie", autopct='%1.1f%%',figsize=(3,3))
plt.title("Gender Ratio")
# Out:
# Text(0.5, 1.0, 'Gender Ratio')

# %%
df.groupby("Gender").size().plot(kind="bar",figsize=(4,4))
plt.title("Gender Ratio")
# Out:
# Text(0.5, 1.0, 'Gender Ratio')

# %%
df.groupby("Gender").sum()["Purchase"]
# Out:
# Gender
# F    144398788.0
# M    499054798.0
# Name: Purchase, dtype: float64

# %%
df.groupby("Gender")['Purchase'].mean().plot(kind="pie",figsize=(4,4),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# **Black Friday-Analysing Age & Martial Status**

# %%
df.groupby("Age").size()
# Out:
# Age
# 0-17      1826
# 18-25    13046
# 26-35    27426
# 36-45    13767
# 46-50     5576
# 51-55     4917
# 55+       2697
# dtype: int64

# %%
df.groupby("Age").size().plot(kind="pie",figsize=(4,4),autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
df.groupby("Age").size().plot(kind="bar",figsize=(4,4),color="blue")
plt.title("Purchase Distribution by age")
# Out:
# Text(0.5, 1.0, 'Purchase Distribution by age')

# %%
for i in df["Age"].unique():
  print(i)
# Out:
# 0-17
# 55+
# 26-35
# 46-50
# 51-55
# 36-45
# 18-25

# %%
df[df["Age"]=="0-17"]
# Out:
#        User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0      1000001  P00069042      F  0-17          10             A
# 1      1000001  P00248942      F  0-17          10             A
# 2      1000001  P00087842      F  0-17          10             A
# 3      1000001  P00085442      F  0-17          10             A
# 85     1000019  P00112542      M  0-17          10             A
# ...        ...        ...    ...   ...         ...           ...
# 69194  1004575  P00193842      F  0-17          10             C
# 69195  1004575  P00258042      F  0-17          10             C
# 69196  1004575  P00122542      F  0-17          10             C
# 69197  1004575  P00241642      F  0-17          10             C
# 69198  1004575  P00070942      F  0-17          10             C
#
#       Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                              2               0                   3    8370.0
# ...

# %%
df[df["Age"]=="18-25"]
# Out:
#        User_ID Product_ID Gender    Age  Occupation City_Category  \
# 70     1000018  P00366542      F  18-25           3             B
# 71     1000018  P00190742      F  18-25           3             B
# 72     1000018  P00151842      F  18-25           3             B
# 73     1000018  P00112642      F  18-25           3             B
# 74     1000018  P00118442      F  18-25           3             B
# ...        ...        ...    ...    ...         ...           ...
# 69239  1004579  P00252042      F  18-25           4             B
# 69240  1004579  P00190942      F  18-25           4             B
# 69241  1004579  P00017742      F  18-25           4             B
# 69242  1004579  P00029542      F  18-25           4             B
# 69243  1004579  P00031042      F  18-25           4             B
#
#       Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 70                             3               0                   5    1780.0
# ...

# %%
len(df[df["Age"]=="18-25"])
# Out:
# 13046

# %%
len(df[df["Age"]=="55+"])
# Out:
# 2697

# %%
df[df["Age"] == i]["Product_ID"].unique()
# Out:
# array(['P00366542', 'P00190742', 'P00151842', ..., 'P00355042',
#        'P00331242', 'P00336042'], dtype=object)

# %%
import pandas as pd
lst=[]
for i in df["Age"].unique():
  lst.append(len(df[df["Age"] == i]["Product_ID"].unique()))
data=pd.DataFrame(lst,index=df["Age"].unique(),columns=["Product_ID"])
data.plot(kind="bar",figsize=(4,4),color="blue")
# Out:
# <Axes: >

# %%
data
# Out:
#        Product_ID
# 0-17         1003
# 55+          1264
# 26-35        2760
# 46-50        1911
# 51-55        1693
# 36-45        2431
# 18-25        2272

# %%
df.groupby("Age").sum()["Purchase"].plot(kind="bar",figsize=(6,4),title="Amount Spend By Age",color="blue")
# Out:
# <Axes: title={'center': 'Amount Spend By Age'}, xlabel='Age'>

# %%
df.groupby("Age").sum()["Purchase"].plot(kind="pie",figsize=(4,4),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("Marital_Status").size().plot(kind="pie",figsize=(4,4),autopct='%1.1f%%')
# Out:
# <Axes: >

# %% [markdown]
# **Black Friday-Multi Column Analysist**

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(6,4)})
sns.countplot(x="Age",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(6,4)})
sns.countplot(x="Gender",hue="Age",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(6,4)})
sns.countplot(x="Gender",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 4))
sns.countplot(x=df["City_Category"],color="blue")
plt.show()

# %%
df.groupby("City_Category").size().plot(kind="pie",figsize=(4,4),autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
sns.countplot(x="City_Category",hue="Gender",data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby("City_Category").sum()["Purchase"].plot(kind="pie",figsize=(4,4),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# **Black Friday-Occupation And Product Analysis**

# %%
sns.countplot(x="Stay_In_Current_City_Years",data=df,color="blue")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# ****

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="City_Category",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby("Stay_In_Current_City_Years").size().plot(kind="pie",figsize=(4,4),autopct="%.1f")
# Out:
# <Axes: >

# %%
df.groupby("Stay_In_Current_City_Years").sum().plot(kind="bar",figsize=(5,4),color="green")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x="Occupation",data=df,color='orange')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation").size().sort_values().plot(kind="bar",color="blue")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").mean(numeric_only=True)["Purchase"].sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
import seaborn as sns
sns.countplot(x="Occupation", hue="Marital_Status", data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
import pandas as pd
df = pd.read_csv('/content/BlackFriday.csv')
df.groupby("Product_Category_1").size().sort_values().plot(kind="bar", color="blue",figsize=(6,4))
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1").mean(numeric_only=True)["Purchase"].sort_values().plot(kind="bar",figsize=(6,4),color="blue")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_ID").sum()["Purchase"].nlargest(10).sort_values().plot(kind="bar",figsize=(6,4),color="blue")
# Out:
# <Axes: xlabel='Product_ID'>

# %%
sns.countplot(x="Product_Category_1", hue="Marital_Status", data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# **Black Friday-Combining Gender & Marital Status**

# %%
l=[]
for i in range(len(df)):
  l.append(df["Gender"][i]+"_"+str(df["Marital_Status"][i]))
df["MaritalGender"] = l
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase MaritalGender
# 0                 NaN                 NaN      8370           F_0
# 1                 6.0                14.0     15200           F_0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 4))
sns.countplot(x=df["MaritalGender"])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 4))
sns.countplot(x=df["Age"], hue=df["MaritalGender"])
plt.show()

# %%
sns.countplot(x=df["Product_Category_1"],hue=df["MaritalGender"])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))
sns.countplot(x=df["Stay_In_Current_City_Years"], hue=df["MaritalGender"])
plt.show()

# %%
figure=plt.figure(figsize=(6,4))
sns.countplot(x=df["Age"],hue=df["MaritalGender"])
# Out:
# <Axes: xlabel='Age', ylabel='count'>
